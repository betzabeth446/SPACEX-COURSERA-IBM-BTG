# %% [markdown]
# Laboratorio práctico: Análisis visual interactivo con Folium
# Objetivos
# Este laboratorio contiene las siguientes tareas:
#
# TAREA 1: Marcar todos los sitios de lanzamiento en un mapa
# TAREA 2: Marcar los lanzamientos exitosos/fallidos para cada sitio en el mapa
# TAREA 3: Calcular las distancias entre un sitio de lanzamiento y sus proximidades
#
# Después de completar las tareas anteriores, deberías ser capaz de identificar algunos patrones geográficos sobre los sitios de lanzamiento.
#
# Primero importemos los paquetes de Python necesarios para este laboratorio:

# %%
# Instalar folium y pandas si no están ya instalados
# !pip install folium pandas

# Luego importar las librerías
import folium
import pandas as pd
import numpy as np
from folium.plugins import MarkerCluster

print("Todo listo para trabajar en el mapa 🌍")
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2025.4.26)
# Todo listo para trabajar en el mapa 🌍

# %%
import folium
import pandas as pd

# %%
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %% [markdown]
# ### **TAREA 1: Marcar todos los sitios de lanzamiento en un mapa**

# %%
# Solo para Google Colab
# !pip install folium pandas
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2025.4.26)

# %%
import folium
import pandas as pd
import numpy as np

# %%
# Datos de ejemplo (puedes reemplazarlos con tus propios datos)
launch_sites = pd.DataFrame({
    'Launch Site': ['CCAFS LC-40', 'VAFB SLC-4E', 'KSC LC-39A', 'CCAFS SLC-40'],
    'Lat': [28.562302, 34.632834, 28.573255, 28.563197],
    'Long': [-80.577356, -120.610746, -80.646895, -80.576820]
})

launch_sites
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1   VAFB SLC-4E  34.632834 -120.610746
# 2    KSC LC-39A  28.573255  -80.646895
# 3  CCAFS SLC-40  28.563197  -80.576820

# %%
# Crear el mapa centrado en EE.UU.
site_map = folium.Map(location=[30, -100], zoom_start=4)

# Agregar un marcador por cada sitio de lanzamiento
for index, row in launch_sites.iterrows():
    folium.Marker(
        location=[row['Lat'], row['Long']],
        popup=row['Launch Site'],
        icon=folium.Icon(color='blue', icon='rocket', prefix='fa')
    ).add_to(site_map)

# Mostrar el mapa
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f24c1ebb219ba16b901482195c6dddd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f24c1ebb219ba16b901482195c6dddd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f24c1ebb219ba16b901482195c6dddd = L.map(
#                 &quot;map_3f24c1ebb219ba16b901482195c6dddd&quot;,
#                 {
#                     center: [30.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e9e9fcc65db6adb875ba1dfe8e86a5e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2e9e9fcc65db6adb875ba1dfe8e86a5e.addTo(map_3f24c1ebb219ba16b901482195c6dddd);
#
#
#             var marker_eeda151a2887fccdd4e5326ad65ccc4a = L.marker(
#                 [28.562302, -80.577356],
#                 {
# }
#             ).addTo(map_3f24c1ebb219ba16b901482195c6dddd);
#
#
#             var icon_3f1b7614371b908370af698602aaa8e7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d294ab4a02094178d0c0b7a3b8964170 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee968093da9d6b572d05ef92e674b69f = $(`&lt;div id=&quot;html_ee968093da9d6b572d05ef92e674b69f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_d294ab4a02094178d0c0b7a3b8964170.setContent(html_ee968093da9d6b572d05ef92e674b69f);
#
#
#
#         marker_eeda151a2887fccdd4e5326ad65ccc4a.bindPopup(popup_d294ab4a02094178d0c0b7a3b8964170)
#         ;
#
#
#
#
#                 marker_eeda151a2887fccdd4e5326ad65ccc4a.setIcon(icon_3f1b7614371b908370af698602aaa8e7);
#
#
#             var marker_e63d62277f82df507fec9cce96b9afd4 = L.marker(
#                 [34.632834, -120.610746],
#                 {
# }
#             ).addTo(map_3f24c1ebb219ba16b901482195c6dddd);
#
#
#             var icon_994633ee9692834bac5fa7b62c515b7d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_243e63c6087a2f8c9a694b641cf4b61d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b143e4cdbc41a8b7ad8c196b346ba6f6 = $(`&lt;div id=&quot;html_b143e4cdbc41a8b7ad8c196b346ba6f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VAFB SLC-4E&lt;/div&gt;`)[0];
#                 popup_243e63c6087a2f8c9a694b641cf4b61d.setContent(html_b143e4cdbc41a8b7ad8c196b346ba6f6);
#
#
#
#         marker_e63d62277f82df507fec9cce96b9afd4.bindPopup(popup_243e63c6087a2f8c9a694b641cf4b61d)
#         ;
#
#
#
#
#                 marker_e63d62277f82df507fec9cce96b9afd4.setIcon(icon_994633ee9692834bac5fa7b62c515b7d);
#
#
#             var marker_d075f7069887aa8624ee5ef93730cf99 = L.marker(
#                 [28.573255, -80.646895],
#                 {
# }
#             ).addTo(map_3f24c1ebb219ba16b901482195c6dddd);
#
#
#             var icon_abf838b9ada42a7d343ab240b5562baa = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9cf0d20044f268dc673039249d14cbea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74fb14b485b6bb5d62cc254789ce3f60 = $(`&lt;div id=&quot;html_74fb14b485b6bb5d62cc254789ce3f60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC-39A&lt;/div&gt;`)[0];
#                 popup_9cf0d20044f268dc673039249d14cbea.setContent(html_74fb14b485b6bb5d62cc254789ce3f60);
#
#
#
#         marker_d075f7069887aa8624ee5ef93730cf99.bindPopup(popup_9cf0d20044f268dc673039249d14cbea)
#         ;
#
#
#
#
#                 marker_d075f7069887aa8624ee5ef93730cf99.setIcon(icon_abf838b9ada42a7d343ab240b5562baa);
#
#
#             var marker_cc98c212cd888ff4e1fe49088dbcedc4 = L.marker(
#                 [28.563197, -80.57682],
#                 {
# }
#             ).addTo(map_3f24c1ebb219ba16b901482195c6dddd);
#
#
#             var icon_0d0c0cee3bc59576595da1ee40d73c32 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quo

# %%
# Mostrar el mapa directamente en Jupyter Notebook
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f24c1ebb219ba16b901482195c6dddd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f24c1ebb219ba16b901482195c6dddd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f24c1ebb219ba16b901482195c6dddd = L.map(
#                 &quot;map_3f24c1ebb219ba16b901482195c6dddd&quot;,
#                 {
#                     center: [30.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e9e9fcc65db6adb875ba1dfe8e86a5e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2e9e9fcc65db6adb875ba1dfe8e86a5e.addTo(map_3f24c1ebb219ba16b901482195c6dddd);
#
#
#             var marker_eeda151a2887fccdd4e5326ad65ccc4a = L.marker(
#                 [28.562302, -80.577356],
#                 {
# }
#             ).addTo(map_3f24c1ebb219ba16b901482195c6dddd);
#
#
#             var icon_3f1b7614371b908370af698602aaa8e7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d294ab4a02094178d0c0b7a3b8964170 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee968093da9d6b572d05ef92e674b69f = $(`&lt;div id=&quot;html_ee968093da9d6b572d05ef92e674b69f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_d294ab4a02094178d0c0b7a3b8964170.setContent(html_ee968093da9d6b572d05ef92e674b69f);
#
#
#
#         marker_eeda151a2887fccdd4e5326ad65ccc4a.bindPopup(popup_d294ab4a02094178d0c0b7a3b8964170)
#         ;
#
#
#
#
#                 marker_eeda151a2887fccdd4e5326ad65ccc4a.setIcon(icon_3f1b7614371b908370af698602aaa8e7);
#
#
#             var marker_e63d62277f82df507fec9cce96b9afd4 = L.marker(
#                 [34.632834, -120.610746],
#                 {
# }
#             ).addTo(map_3f24c1ebb219ba16b901482195c6dddd);
#
#
#             var icon_994633ee9692834bac5fa7b62c515b7d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_243e63c6087a2f8c9a694b641cf4b61d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b143e4cdbc41a8b7ad8c196b346ba6f6 = $(`&lt;div id=&quot;html_b143e4cdbc41a8b7ad8c196b346ba6f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VAFB SLC-4E&lt;/div&gt;`)[0];
#                 popup_243e63c6087a2f8c9a694b641cf4b61d.setContent(html_b143e4cdbc41a8b7ad8c196b346ba6f6);
#
#
#
#         marker_e63d62277f82df507fec9cce96b9afd4.bindPopup(popup_243e63c6087a2f8c9a694b641cf4b61d)
#         ;
#
#
#
#
#                 marker_e63d62277f82df507fec9cce96b9afd4.setIcon(icon_994633ee9692834bac5fa7b62c515b7d);
#
#
#             var marker_d075f7069887aa8624ee5ef93730cf99 = L.marker(
#                 [28.573255, -80.646895],
#                 {
# }
#             ).addTo(map_3f24c1ebb219ba16b901482195c6dddd);
#
#
#             var icon_abf838b9ada42a7d343ab240b5562baa = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9cf0d20044f268dc673039249d14cbea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74fb14b485b6bb5d62cc254789ce3f60 = $(`&lt;div id=&quot;html_74fb14b485b6bb5d62cc254789ce3f60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC-39A&lt;/div&gt;`)[0];
#                 popup_9cf0d20044f268dc673039249d14cbea.setContent(html_74fb14b485b6bb5d62cc254789ce3f60);
#
#
#
#         marker_d075f7069887aa8624ee5ef93730cf99.bindPopup(popup_9cf0d20044f268dc673039249d14cbea)
#         ;
#
#
#
#
#                 marker_d075f7069887aa8624ee5ef93730cf99.setIcon(icon_abf838b9ada42a7d343ab240b5562baa);
#
#
#             var marker_cc98c212cd888ff4e1fe49088dbcedc4 = L.marker(
#                 [28.563197, -80.57682],
#                 {
# }
#             ).addTo(map_3f24c1ebb219ba16b901482195c6dddd);
#
#
#             var icon_0d0c0cee3bc59576595da1ee40d73c32 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quo

# %% [markdown]
# Primero, intentemos agregar la ubicación de cada sitio en un mapa usando las coordenadas de latitud y longitud del sitio.
#
# El siguiente conjunto de datos, llamado spacex_launch_geo.csv, es un conjunto de datos ampliado que incluye la latitud y longitud agregadas para cada sitio.

# %%
# Importar pandas
import pandas as pd

# URL del dataset
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'

# Leer el CSV directamente desde la URL
spacex_df = pd.read_csv(url)

# Mostrar las primeras filas del DataFrame
spacex_df.head()
# Out:
#    Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# 0              1  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1              2  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2              3  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3              4  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4              5  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  Payload Mass (kg)  \
# 0               Dragon Spacecraft Qualification Unit                0.0
# 1  Dragon demo flight C1, two CubeSats,  barrel o...                0.0
# 2                             Dragon demo flight C2+              525.0
# 3                                       SpaceX CRS-1              500.0
# 4                                       SpaceX CRS-2              677.0
#
#        Orbit         Customer        Landing Outcome  class        Lat  \
# 0        LEO           SpaceX  Failure   (parachute)      0  28.562302
# 1  LEO (ISS)  NASA (COTS) NRO  Failure   (parachute)      0  28.562302
# 2  LEO (ISS)      NASA (COTS)             No attempt      0  28.562302
# 3  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
# 4  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
#
#         Long
# 0 -80.577356
# 1 -80.577356
# 2 -80.577356
# 3 -80.577356
# 4 -80.577356

# %%
# Select relevant sub-columns: `Launch Site`, `Lat(Latitude)`, `Long(Longitude)`, `class`
spacex_df = spacex_df[['Launch Site', 'Lat', 'Long', 'class']]
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %% [markdown]
# Las coordenadas anteriores son solo números simples que no pueden darte una idea intuitiva de dónde están ubicados esos sitios de lanzamiento.
# Si eres muy buena en geografía, puedes interpretar esos números directamente en tu mente.
# Si no, también está bien. Vamos a visualizar esas ubicaciones colocándolas en un mapa.
#
# Primero necesitamos crear un objeto Map de Folium, con una ubicación inicial centrada en el Centro Espacial Johnson de la NASA en Houston, Texas.

# %%
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %% [markdown]
# Podemos usar folium.Circle para agregar un área circular resaltada con una etiqueta de texto en una coordenada específica. Por ejemplo:

# %%
# Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0487e1ed3ab831ea1145742b1570aaa7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0487e1ed3ab831ea1145742b1570aaa7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0487e1ed3ab831ea1145742b1570aaa7 = L.map(
#                 &quot;map_0487e1ed3ab831ea1145742b1570aaa7&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6e5b2640b6840aabebd4ff541ada516 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a6e5b2640b6840aabebd4ff541ada516.addTo(map_0487e1ed3ab831ea1145742b1570aaa7);
#
#
#             var circle_1601aab5f8173deecc1c5e8750991fd6 = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0487e1ed3ab831ea1145742b1570aaa7);
#
#
#         var popup_4b5d408b2372513e2de13d9938f4aeb6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55a3d4ea0fd4fba49d425a53d7746670 = $(`&lt;div id=&quot;html_55a3d4ea0fd4fba49d425a53d7746670&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_4b5d408b2372513e2de13d9938f4aeb6.setContent(html_55a3d4ea0fd4fba49d425a53d7746670);
#
#
#
#         circle_1601aab5f8173deecc1c5e8750991fd6.bindPopup(popup_4b5d408b2372513e2de13d9938f4aeb6)
#         ;
#
#
#
#
#             var marker_3e02d33a740be3db2cc8e25b7a35bc3a = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_0487e1ed3ab831ea1145742b1570aaa7);
#
#
#             var div_icon_8f82322a77adb332a9a499e8f2675360 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_3e02d33a740be3db2cc8e25b7a35bc3a.setIcon(div_icon_8f82322a77adb332a9a499e8f2675360);
#
#
#                 marker_3e02d33a740be3db2cc8e25b7a35bc3a.setIcon(div_icon_8f82322a77adb332a9a499e8f2675360);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Y deberías encontrar un pequeño círculo amarillo cerca de la ciudad de Houston. Puedes hacer zoom para ver un círculo más grande.
#
# Ahora, agreguemos un círculo para cada sitio de lanzamiento en el DataFrame launch_sites.
#
# POR HACER (TODO): Crear y agregar folium.Circle y folium.Marker para cada sitio de lanzamiento en el mapa (site_map).
#
# Un ejemplo de uso de folium.Circle:

# %%
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# Add the initial NASA JSC circle and marker as in the original code
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)

# Assuming launch_sites_df is already loaded from a previous cell
# Iterate through each launch site in the DataFrame
for index, site_info in launch_sites_df.iterrows():
    # Get the coordinates and launch site name
    site_coordinate = [site_info['Lat'], site_info['Long']]
    site_name = site_info['Launch Site']

    # Create a Circle for the launch site
    # You can customize radius, color, and fill based on requirements
    site_circle = folium.Circle(
        site_coordinate,
        radius=1000, # Example radius, adjust as needed
        color='#000000', # Example color
        fill=True,
        fill_color='#000000' # Example fill color
    ).add_child(folium.Popup(site_name)) # Add popup with site name

    # Create a Marker for the launch site with a text label
    site_marker = folium.map.Marker(
        site_coordinate,
        # Create an icon as a text label
        icon=DivIcon(
            icon_size=(20,20),
            icon_anchor=(0,0),
            html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % site_name,
            )
        )

    # Add the circle and marker to the map
    site_map.add_child(site_circle)
    site_map.add_child(site_marker)

# Display the map (this would typically be the last line in a cell in a notebook)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a93a94a4ec5375decedff1d62b06a7b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a93a94a4ec5375decedff1d62b06a7b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a93a94a4ec5375decedff1d62b06a7b9 = L.map(
#                 &quot;map_a93a94a4ec5375decedff1d62b06a7b9&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_241a65c49aa9fb8e884ad83358c4d3aa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_241a65c49aa9fb8e884ad83358c4d3aa.addTo(map_a93a94a4ec5375decedff1d62b06a7b9);
#
#
#             var circle_942c5be102ecc8bd711a304076356f2f = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a93a94a4ec5375decedff1d62b06a7b9);
#
#
#         var popup_1e8e3e2d9d2524935a24408312551429 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_057d5f8d136413ba31e575394e243e45 = $(`&lt;div id=&quot;html_057d5f8d136413ba31e575394e243e45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_1e8e3e2d9d2524935a24408312551429.setContent(html_057d5f8d136413ba31e575394e243e45);
#
#
#
#         circle_942c5be102ecc8bd711a304076356f2f.bindPopup(popup_1e8e3e2d9d2524935a24408312551429)
#         ;
#
#
#
#
#             var marker_242d158f91d7f326834a787fe13edb15 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_a93a94a4ec5375decedff1d62b06a7b9);
#
#
#             var div_icon_657c42e5386490211dffc3fd29a59bac = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_242d158f91d7f326834a787fe13edb15.setIcon(div_icon_657c42e5386490211dffc3fd29a59bac);
#
#
#                 marker_242d158f91d7f326834a787fe13edb15.setIcon(div_icon_657c42e5386490211dffc3fd29a59bac);
#
#
#             var circle_61153ae762f94f1f61133a7880d5e264 = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a93a94a4ec5375decedff1d62b06a7b9);
#
#
#         var popup_11a88e512dd356b2c2ad95d3010ac7fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b655cf47ed8ff9da363286d18b9470a4 = $(`&lt;div id=&quot;html_b655cf47ed8ff9da363286d18b9470a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_11a88e512dd356b2c2ad95d3010ac7fb.setContent(html_b655cf47ed8ff9da363286d18b9470a4);
#
#
#
#         circle_61153ae762f94f1f61133a7880d5e264.bindPopup(popup_11a88e512dd356b2c2ad95d3010ac7fb)
#         ;
#
#
#
#
#             var marker_0ec494ab358eab191b76a8d81222d5d8 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_a93a94a4ec5375decedff1d62b06a7b9);
#
#
#             var div_icon_1fdd7494d6abee7081c9e5e224743875 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_0ec494ab358eab191b76a8d81222d5d8.setIcon(div_icon_1fdd7494d6abee7081c9e5e224743875);
#
#
#                 marker_0ec494ab358eab191b76a8d81222d5d8.setIcon(div_icon_1fdd7494d6abee

# %% [markdown]
# An example of folium.Marker:

# %%
import folium

# Crear mapa centrado en Houston, Texas
nasa_coordinates = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinates, zoom_start=10)

# Agregar un círculo
folium.Circle(
    location=nasa_coordinates,
    radius=1000,
    color='yellow',
    fill=True,
    fill_color='yellow',
    popup='NASA Johnson Space Center'
).add_to(site_map)

# Agregar un marcador
folium.Marker(
    location=nasa_coordinates,
    popup='NASA Johnson Space Center',
    icon=folium.Icon(color='green')
).add_to(site_map)

# Mostrar mapa
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_14aeec9fc4b6ca4f1b5f054f1cdad87e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_14aeec9fc4b6ca4f1b5f054f1cdad87e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_14aeec9fc4b6ca4f1b5f054f1cdad87e = L.map(
#                 &quot;map_14aeec9fc4b6ca4f1b5f054f1cdad87e&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c56baed8d471fcb668d5d84d1276bb9e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c56baed8d471fcb668d5d84d1276bb9e.addTo(map_14aeec9fc4b6ca4f1b5f054f1cdad87e);
#
#
#             var circle_28745a678162f76f0ccb2cf5316764cf = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_14aeec9fc4b6ca4f1b5f054f1cdad87e);
#
#
#         var popup_41f470370a1cd8ab40ac47c0a9a59063 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53637c9e4dcc9920140a16335965a4b1 = $(`&lt;div id=&quot;html_53637c9e4dcc9920140a16335965a4b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_41f470370a1cd8ab40ac47c0a9a59063.setContent(html_53637c9e4dcc9920140a16335965a4b1);
#
#
#
#         circle_28745a678162f76f0ccb2cf5316764cf.bindPopup(popup_41f470370a1cd8ab40ac47c0a9a59063)
#         ;
#
#
#
#
#             var marker_333bfc519ec10aa9db840e51fa792404 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_14aeec9fc4b6ca4f1b5f054f1cdad87e);
#
#
#             var icon_f358670a4d6bb751d3df591c31303935 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_19f961d7588b753a16efb35bca95c3a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f55c1ba1f3b066df22683590cf6e83c5 = $(`&lt;div id=&quot;html_f55c1ba1f3b066df22683590cf6e83c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_19f961d7588b753a16efb35bca95c3a2.setContent(html_f55c1ba1f3b066df22683590cf6e83c5);
#
#
#
#         marker_333bfc519ec10aa9db840e51fa792404.bindPopup(popup_19f961d7588b753a16efb35bca95c3a2)
#         ;
#
#
#
#
#                 marker_333bfc519ec10aa9db840e51fa792404.setIcon(icon_f358670a4d6bb751d3df591c31303935);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Initial the map
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)
# For each launch site, add a Circle object based on its coordinate (Lat, Long) values. In addition, add Launch site name as a popup label

# %% [markdown]
# El mapa generado con los sitios de lanzamiento marcados debería verse similar al siguiente:

# %% [markdown]
# Ahora puedes explorar el mapa haciendo zoom in / out en las áreas marcadas, y tratar de responder las siguientes preguntas:
#
# ¿Están todos los sitios de lanzamiento cerca de la línea del Ecuador?
#
# ¿Están todos los sitios de lanzamiento muy cerca de la costa?
#
# Además, intenta explicar tus hallazgos.

# %%
import folium

# Crear mapa centrado en EE.UU.
site_map = folium.Map(location=[28.5, -80.5], zoom_start=5)

# Recorrer cada fila del DataFrame
for index, row in spacex_df.iterrows():
    lat = row['Lat']
    lon = row['Long']
    outcome = row['class']
    site = row['Launch Site']

    # Elegir color según éxito o fallo
    color = 'green' if outcome == 1 else 'red'
    label = 'Success' if outcome == 1 else 'Failure'

    # Agregar marcador al mapa
    folium.Marker(
        location=[lat, lon],
        popup=f"{site} - {label}",
        icon=folium.Icon(color=color)
    ).add_to(site_map)

# Mostrar mapa
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_05477a4b518a1c74444ee47b86d029f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_05477a4b518a1c74444ee47b86d029f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_05477a4b518a1c74444ee47b86d029f6 = L.map(
#                 &quot;map_05477a4b518a1c74444ee47b86d029f6&quot;,
#                 {
#                     center: [28.5, -80.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_65f9be710b3403536f1df24c7a5a8fcb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_65f9be710b3403536f1df24c7a5a8fcb.addTo(map_05477a4b518a1c74444ee47b86d029f6);
#
#
#             var marker_3a5d180d74ff2b823228514b357b8f5b = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_05477a4b518a1c74444ee47b86d029f6);
#
#
#             var icon_318bcc04d509ce0d9d19811650d480c5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_29ac7cb51c722273c7bccb642187c2aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca1877d7ad7a2392f23241f0891d5978 = $(`&lt;div id=&quot;html_ca1877d7ad7a2392f23241f0891d5978&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_29ac7cb51c722273c7bccb642187c2aa.setContent(html_ca1877d7ad7a2392f23241f0891d5978);
#
#
#
#         marker_3a5d180d74ff2b823228514b357b8f5b.bindPopup(popup_29ac7cb51c722273c7bccb642187c2aa)
#         ;
#
#
#
#
#                 marker_3a5d180d74ff2b823228514b357b8f5b.setIcon(icon_318bcc04d509ce0d9d19811650d480c5);
#
#
#             var marker_87fc25e5f02fae0d183e8a8022746cee = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_05477a4b518a1c74444ee47b86d029f6);
#
#
#             var icon_96527a9ccacbee48c02430c40e414a85 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8ee7c15af9f105c76ca2fd02d7012a4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_002da252cacccabfd835bdc10008b00d = $(`&lt;div id=&quot;html_002da252cacccabfd835bdc10008b00d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_8ee7c15af9f105c76ca2fd02d7012a4f.setContent(html_002da252cacccabfd835bdc10008b00d);
#
#
#
#         marker_87fc25e5f02fae0d183e8a8022746cee.bindPopup(popup_8ee7c15af9f105c76ca2fd02d7012a4f)
#         ;
#
#
#
#
#                 marker_87fc25e5f02fae0d183e8a8022746cee.setIcon(icon_96527a9ccacbee48c02430c40e414a85);
#
#
#             var marker_ad5cdfcae67e125094bcb5363997bf95 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_05477a4b518a1c74444ee47b86d029f6);
#
#
#             var icon_5c7fe7b0ebd05484c22ba7f9e6562df4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_941ce9aa1442470cd779d59be898fbc7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88342d2942b694feaae8c0296222ebb2 = $(`&lt;div id=&quot;html_88342d2942b694feaae8c0296222ebb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_941ce9aa1442470cd779d59be898fbc7.setContent(html_88342d2942b694feaae8c0296222ebb2);
#
#
#
#         marker_ad5cdfcae67e125094bcb5363997bf95.bindPopup(popup_941ce9aa1442470cd779d59be898fbc7)
#         ;
#
#
#
#
#                 marker_ad5cdfcae67e125094bcb5363997bf95.setIcon(icon_5c7fe7b0ebd05484c22ba7f9e6562df4);
#
#
#             var marker_ae9f10c0e554d4971cfaa7efa61a303f = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_05477a4b518a1c74444ee47b86d029f6);
#
#
#             var icon_61325b6e1d9d0121e6f9b34fb5

# %% [markdown]
# A continuación, intentemos mejorar el mapa agregando los resultados de los lanzamientos para cada sitio, y veamos cuáles tienen una alta tasa de éxito.
# Recuerda que el DataFrame spacex_df contiene registros detallados de los lanzamientos, y que la columna class indica si el lanzamiento fue exitoso o no.

# %%
spacex_df.tail(10)
# Out:
#      Launch Site        Lat       Long  class
# 46    KSC LC-39A  28.573255 -80.646895      1
# 47    KSC LC-39A  28.573255 -80.646895      1
# 48    KSC LC-39A  28.573255 -80.646895      1
# 49  CCAFS SLC-40  28.563197 -80.576820      1
# 50  CCAFS SLC-40  28.563197 -80.576820      1
# 51  CCAFS SLC-40  28.563197 -80.576820      0
# 52  CCAFS SLC-40  28.563197 -80.576820      0
# 53  CCAFS SLC-40  28.563197 -80.576820      0
# 54  CCAFS SLC-40  28.563197 -80.576820      1
# 55  CCAFS SLC-40  28.563197 -80.576820      0

# %% [markdown]
# A continuación, creemos marcadores para todos los registros de lanzamiento. Si un lanzamiento fue exitoso (class = 1), usamos un marcador verde, y si el lanzamiento falló (class = 0), usamos un marcador rojo.
#
# Ten en cuenta que un lanzamiento solo ocurre en uno de los cuatro sitios de lanzamiento, lo que significa que muchos registros de lanzamiento tendrán exactamente las mismas coordenadas. Los clústeres de marcadores (Marker Clusters) pueden ser una buena forma de simplificar un mapa que contiene muchos marcadores en la misma ubicación.
#
# Primero, creemos un objeto MarkerCluster.

# %%
marker_cluster = MarkerCluster()

# %% [markdown]
#  (TODO): Crea una nueva columna en el DataFrame spacex_df llamada marker_color para almacenar los colores de los marcadores según el valor de la columna class.

# %%
# Aplicar una función para verificar el valor de la columna `class`
# Si class = 1, el valor de marker_color será 'green'
# Si class = 0, el valor de marker_color será 'red'

spacex_df['marker_color'] = spacex_df['class'].apply(lambda x: 'green' if x == 1 else 'red')

# Verificar las primeras filas
spacex_df[['Launch Site', 'class', 'marker_color']].head()
# Out:
#    Launch Site  class marker_color
# 0  CCAFS LC-40      0          red
# 1  CCAFS LC-40      0          red
# 2  CCAFS LC-40      0          red
# 3  CCAFS LC-40      0          red
# 4  CCAFS LC-40      0          red

# %% [markdown]
# (TODO): Para cada resultado de lanzamiento en el DataFrame spacex_df, agrega un folium.Marker al marker_cluster.

# %%
# Add marker_cluster to current site_map
site_map.add_child(marker_cluster)

# for each row in spacex_df data frame
# create a Marker object with its coordinate
# and customize the Marker's icon property to indicate if this launch was successed or failed,
# e.g., icon=folium.Icon(color='white', icon_color=row['marker_color']
for index, record in spacex_df.iterrows():
    # TODO: Create and add a Marker cluster to the site map
    # marker = folium.Marker(...)
    marker_cluster.add_child(marker)

site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_05477a4b518a1c74444ee47b86d029f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_05477a4b518a1c74444ee47b86d029f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_05477a4b518a1c74444ee47b86d029f6 = L.map(
#                 &quot;map_05477a4b518a1c74444ee47b86d029f6&quot;,
#                 {
#                     center: [28.5, -80.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_65f9be710b3403536f1df24c7a5a8fcb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_65f9be710b3403536f1df24c7a5a8fcb.addTo(map_05477a4b518a1c74444ee47b86d029f6);
#
#
#             var marker_3a5d180d74ff2b823228514b357b8f5b = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_05477a4b518a1c74444ee47b86d029f6);
#
#
#             var icon_318bcc04d509ce0d9d19811650d480c5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_29ac7cb51c722273c7bccb642187c2aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca1877d7ad7a2392f23241f0891d5978 = $(`&lt;div id=&quot;html_ca1877d7ad7a2392f23241f0891d5978&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_29ac7cb51c722273c7bccb642187c2aa.setContent(html_ca1877d7ad7a2392f23241f0891d5978);
#
#
#
#         marker_3a5d180d74ff2b823228514b357b8f5b.bindPopup(popup_29ac7cb51c722273c7bccb642187c2aa)
#         ;
#
#
#
#
#                 marker_3a5d180d74ff2b823228514b357b8f5b.setIcon(icon_318bcc04d509ce0d9d19811650d480c5);
#
#
#             var marker_87fc25e5f02fae0d183e8a8022746cee = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_05477a4b518a1c74444ee47b86d029f6);
#
#
#             var icon_96527a9ccacbee48c02430c40e414a85 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8ee7c15af9f105c76ca2fd02d7012a4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_002da252cacccabfd835bdc10008b00d = $(`&lt;div id=&quot;html_002da252cacccabfd835bdc10008b00d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_8ee7c15af9f105c76ca2fd02d7012a4f.setContent(html_002da252cacccabfd835bdc10008b00d);
#
#
#
#         marker_87fc25e5f02fae0d183e8a8022746cee.bindPopup(popup_8ee7c15af9f105c76ca2fd02d7012a4f)
#         ;
#
#
#
#
#                 marker_87fc25e5f02fae0d183e8a8022746cee.setIcon(icon_96527a9ccacbee48c02430c40e414a85);
#
#
#             var marker_ad5cdfcae67e125094bcb5363997bf95 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_05477a4b518a1c74444ee47b86d029f6);
#
#
#             var icon_5c7fe7b0ebd05484c22ba7f9e6562df4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_941ce9aa1442470cd779d59be898fbc7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88342d2942b694feaae8c0296222ebb2 = $(`&lt;div id=&quot;html_88342d2942b694feaae8c0296222ebb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_941ce9aa1442470cd779d59be898fbc7.setContent(html_88342d2942b694feaae8c0296222ebb2);
#
#
#
#         marker_ad5cdfcae67e125094bcb5363997bf95.bindPopup(p

# %%
import folium
from folium.plugins import MarkerCluster

# Crear el mapa centrado en la costa de Florida
launch_map = folium.Map(location=[28.5, -80.5], zoom_start=5)

# Crear objeto MarkerCluster
marker_cluster = MarkerCluster().add_to(launch_map)

# Recorrer cada fila del DataFrame y agregar marcadores al cluster
for index, row in spacex_df.iterrows():
    folium.Marker(
        location=[row['Lat'], row['Long']],
        popup=f"{row['Launch Site']} - {'Success' if row['class'] == 1 else 'Failure'}",
        icon=folium.Icon(color=row['marker_color'])
    ).add_to(marker_cluster)

# Mostrar el mapa
launch_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f6a2736f2f0fc882e80e0c658024141 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f6a2736f2f0fc882e80e0c658024141&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2f6a2736f2f0fc882e80e0c658024141 = L.map(
#                 &quot;map_2f6a2736f2f0fc882e80e0c658024141&quot;,
#                 {
#                     center: [28.5, -80.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_571e5ad98a59f081b72b46aeba25904a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_571e5ad98a59f081b72b46aeba25904a.addTo(map_2f6a2736f2f0fc882e80e0c658024141);
#
#
#             var marker_cluster_061960963e4745a3d14e3226e460939c = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_f6c72ff24c9cfb85155a9a4f6c5df3a9 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_061960963e4745a3d14e3226e460939c);
#
#
#             var icon_ddf7d68ac1af749732285efb6d1196ee = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9d1fe671bb6417e2acb9d37efe5b301e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce108f0a7028185701e5f2cb01a01184 = $(`&lt;div id=&quot;html_ce108f0a7028185701e5f2cb01a01184&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_9d1fe671bb6417e2acb9d37efe5b301e.setContent(html_ce108f0a7028185701e5f2cb01a01184);
#
#
#
#         marker_f6c72ff24c9cfb85155a9a4f6c5df3a9.bindPopup(popup_9d1fe671bb6417e2acb9d37efe5b301e)
#         ;
#
#
#
#
#                 marker_f6c72ff24c9cfb85155a9a4f6c5df3a9.setIcon(icon_ddf7d68ac1af749732285efb6d1196ee);
#
#
#             var marker_76a1d6e12ebdbe8fd7a177e71ef29ed3 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_061960963e4745a3d14e3226e460939c);
#
#
#             var icon_4721a25e4ec77db46b9272badd264e3d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5e79a34bcb0a0c7c080995ea3b48cdbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd671b0b18dd0429c45d18f6e17aaccb = $(`&lt;div id=&quot;html_dd671b0b18dd0429c45d18f6e17aaccb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_5e79a34bcb0a0c7c080995ea3b48cdbd.setContent(html_dd671b0b18dd0429c45d18f6e17aaccb);
#
#
#
#         marker_76a1d6e12ebdbe8fd7a177e71ef29ed3.bindPopup(popup_5e79a34bcb0a0c7c080995ea3b48cdbd)
#         ;
#
#
#
#
#                 marker_76a1d6e12ebdbe8fd7a177e71ef29ed3.setIcon(icon_4721a25e4ec77db46b9272badd264e3d);
#
#
#             var marker_35543aed2196cd3e76e28fc4fd7099b8 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_061960963e4745a3d14e3226e460939c);
#
#
#             var icon_167aa2340d5f40e26d407e98df78e221 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1ab08c9a513abf79b346498ad12b4de1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f2d964b2e466018866cd70b42cc7d0b = $(`&lt;div id=&quot;html_5f2d964b2e466018866cd70b42cc7d0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 po

# %% [markdown]
# A partir de los marcadores codificados por color dentro de los clústeres, deberías poder identificar fácilmente qué sitios de lanzamiento tienen tasas de éxito relativamente altas.

# %% [markdown]
# TAREA 3: Calcular las distancias entre un sitio de lanzamiento y sus proximidades

# %% [markdown]
# A continuación, necesitamos explorar y analizar las proximidades de los sitios de lanzamiento.
#
# Primero, agreguemos la herramienta MousePosition al mapa para obtener las coordenadas al pasar el mouse sobre un punto del mapa.
# De esta forma, mientras exploras el mapa, podrás encontrar fácilmente las coordenadas de cualquier punto de interés (como una vía de tren, por ejemplo).

# %%
# Add Mouse Position to get the coordinate (Lat, Long) for a mouse over on the map
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_05477a4b518a1c74444ee47b86d029f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_05477a4b518a1c74444ee47b86d029f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_05477a4b518a1c74444ee47b86d029f6 = L.map(
#                 &quot;map_05477a4b518a1c74444ee47b86d029f6&quot;,
#                 {
#                     center: [28.5, -80.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_65f9be710b3403536f1df24c7a5a8fcb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_65f9be710b3403536f1df24c7a5a8fcb.addTo(map_05477a4b518a1c74444ee47b86d029f6);
#
#
#             var marker_3a5d180d74ff2b823228514b357b8f5b = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_05477a4b518a1c74444ee47b86d029f6);
#
#
#             var icon_318bcc04d509ce0d9d19811650d480c5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_29ac7cb51c722273c7bccb642187c2aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca1877d7ad7a2392f23241f0891d5978 = $(`&lt;div id=&quot;html_ca1877d7ad7a2392f23241f0891d5978&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_29ac7cb51c722273c7bccb642187c2aa.setContent(html_ca1877d7ad7a2392f23241f0891d5978);
#
#
#
#         marker_3a5d180d74ff2b823228514b357b8f5b.bindPopup(popup_29ac7cb51c722273c7bccb642187c2aa)
#         ;
#
#
#
#
#                 marker_3a5d180d74ff2b823228514b357b8f5b.setIcon(icon_318bcc04d509ce0d9d19811650d480c5);
#
#
#             var marker_87fc25e5f02fae0d183e8a8022746cee = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_05477a4b518a1c74444ee47b86d029f6);
#
#
#             var icon_96527a9ccacbee48c02430c40e414a85 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8ee7c15af9f105c76ca2fd02d7012a4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_002da252cacccabfd835bdc10008b00d = $(`&lt;div id=&quot;html_002da252cacccabfd835bdc10008b00d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_8ee7c15af9f105c76ca2fd02d7012a4f.setContent(html_002da252cacccabfd835bdc10008b00d);
#
#
#
#         marker_87fc25e5f02fae0d183e8a8022746cee.bindPopup(popup_8ee7c15af9f105c76ca2fd02d7012a4f)
#         ;
#
#
#
#
#                 marker_87fc25e5f02fae0d183e8a8022746cee.setIcon(icon_96527a9ccacbee48c02430c40e414a85);
#
#
#             var marker_ad5cdfcae67e125094bcb5363997bf95 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_05477a4b518a1c74444ee47b86d029f6);
#
#
#             var icon_5c7fe7b0ebd05484c22ba7f9e6562df4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_941ce9aa1442470cd779d59be898fbc7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88342d2942b694feaae8c0296222ebb2 = $(`&lt;div id=&quot;html_88342d2942b694feaae8c029

# %% [markdown]
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.
#
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.

# %%
# Add Mouse Position to get the coordinate (Lat, Long) for a mouse over on the map
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fed65e3b8d91e9c4cff242b834cef8bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fed65e3b8d91e9c4cff242b834cef8bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fed65e3b8d91e9c4cff242b834cef8bb = L.map(
#                 &quot;map_fed65e3b8d91e9c4cff242b834cef8bb&quot;,
#                 {
#                     center: [28.5, -80.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36617df358048839ebaf7dad2e72993c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_36617df358048839ebaf7dad2e72993c.addTo(map_fed65e3b8d91e9c4cff242b834cef8bb);
#
#
#             var mouse_position_d134a1f263c57375dd49d053bf7aa321 = new L.Control.MousePosition(
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;separator&quot;: &quot; Long: &quot;,
#   &quot;emptyString&quot;: &quot;NaN&quot;,
#   &quot;lngFirst&quot;: false,
#   &quot;numDigits&quot;: 20,
#   &quot;prefix&quot;: &quot;Lat:&quot;,
# }
#             );
#             mouse_position_d134a1f263c57375dd49d053bf7aa321.options[&quot;latFormatter&quot;] =
#                 function(num) {return L.Util.formatNum(num, 5);};;
#             mouse_position_d134a1f263c57375dd49d053bf7aa321.options[&quot;lngFormatter&quot;] =
#                 function(num) {return L.Util.formatNum(num, 5);};;
#             map_fed65e3b8d91e9c4cff242b834cef8bb.addControl(mouse_position_d134a1f263c57375dd49d053bf7aa321);
#
#
#             tile_layer_36617df358048839ebaf7dad2e72993c.addTo(map_fed65e3b8d91e9c4cff242b834cef8bb);
#
#
#             var mouse_position_2095be00910147e47790a710235daa42 = new L.Control.MousePosition(
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;separator&quot;: &quot; Long: &quot;,
#   &quot;emptyString&quot;: &quot;NaN&quot;,
#   &quot;lngFirst&quot;: false,
#   &quot;numDigits&quot;: 20,
#   &quot;prefix&quot;: &quot;Lat:&quot;,
# }
#             );
#             mouse_position_2095be00910147e47790a710235daa42.options[&quot;latFormatter&quot;] =
#                 function(num) {return L.Util.formatNum(num, 5);};;
#             mouse_position_2095be00910147e47790a710235daa42.options[&quot;lngFormatter&quot;] =
#                 function(num) {return L.Util.formatNum(num, 5);};;
#             map_fed65e3b8d91e9c4cff242b834cef8bb.addControl(mouse_position_2095be00910147e47790a710235daa42);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from math import sin, cos, sqrt, atan2, radians

def calculate_distance(lat1, lon1, lat2, lon2):
    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

# %% [markdown]
# TODO: Mark down a point on the closest coastline using MousePosition and calculate the distance between the coastline point and the launch site.

# %%
# Coordenadas del sitio de lanzamiento
launch_site_lat = 28.5623
launch_site_lon = -80.5774

# Coordenadas del punto más cercano en la costa (obtenidas con MousePosition)
coastline_lat = 28.56367
coastline_lon = -80.57163

# %%
# !pip install geopy

from geopy.distance import geodesic

# Definir la función
def calculate_distance(lat1, lon1, lat2, lon2):
    point1 = (lat1, lon1)
    point2 = (lat2, lon2)
    return geodesic(point1, point2).km

# Calcular la distancia
distance_coastline = calculate_distance(launch_site_lat, launch_site_lon, coastline_lat, coastline_lon)

print(f"La distancia entre el sitio de lanzamiento y la costa es de aproximadamente {distance_coastline:.2f} km.")
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.11/dist-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.11/dist-packages (from geopy) (2.0)
# La distancia entre el sitio de lanzamiento y la costa es de aproximadamente 0.58 km.

# %%
import folium
from folium.features import DivIcon
from math import radians, cos, sin, asin, sqrt

# Función Haversine para calcular distancia en kilómetros
def haversine(lat1, lon1, lat2, lon2):
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    r = 6371  # Radio de la Tierra en km
    return c * r

# Coordenadas del sitio de lanzamiento y punto en la costa
launch_site = [28.5623, -80.5774]
coastline = [28.56367, -80.57163]

# Calcular distancia
distance = haversine(launch_site[0], launch_site[1], coastline[0], coastline[1])

# Crear el mapa centrado en el sitio de lanzamiento
site_map = folium.Map(location=launch_site, zoom_start=14)

# Agregar marcador en el sitio de lanzamiento
folium.Marker(
    launch_site,
    popup='Launch Site',
    icon=folium.Icon(color='blue')
).add_to(site_map)

# Agregar marcador en la costa
folium.Marker(
    coastline,
    popup='Coastline Point',
    icon=folium.Icon(color='green')
).add_to(site_map)

# Agregar texto de distancia en el punto costero
folium.Marker(
    location=coastline,
    icon=DivIcon(
        icon_size=(150,36),
        icon_anchor=(0,0),
        html='<div style="font-size: 12px; color:#d35400;"><b>{:.2f} KM</b></div>'.format(distance),
    )
).add_to(site_map)

# Mostrar el mapa
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4c1bb916239ded3bc1967bac8c86dca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4c1bb916239ded3bc1967bac8c86dca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4c1bb916239ded3bc1967bac8c86dca = L.map(
#                 &quot;map_a4c1bb916239ded3bc1967bac8c86dca&quot;,
#                 {
#                     center: [28.5623, -80.5774],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d52fec5abfe0166ff4d5fe494c593f8d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d52fec5abfe0166ff4d5fe494c593f8d.addTo(map_a4c1bb916239ded3bc1967bac8c86dca);
#
#
#             var marker_6aef105e3fce3f96055ccd7ee662a743 = L.marker(
#                 [28.5623, -80.5774],
#                 {
# }
#             ).addTo(map_a4c1bb916239ded3bc1967bac8c86dca);
#
#
#             var icon_80fb8a021a2d1abc3a1e4fa041b2886b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_381a6d82382a4827f74742a64483326a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8235aa980baa9233f7f41cff475f2b0 = $(`&lt;div id=&quot;html_f8235aa980baa9233f7f41cff475f2b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site&lt;/div&gt;`)[0];
#                 popup_381a6d82382a4827f74742a64483326a.setContent(html_f8235aa980baa9233f7f41cff475f2b0);
#
#
#
#         marker_6aef105e3fce3f96055ccd7ee662a743.bindPopup(popup_381a6d82382a4827f74742a64483326a)
#         ;
#
#
#
#
#                 marker_6aef105e3fce3f96055ccd7ee662a743.setIcon(icon_80fb8a021a2d1abc3a1e4fa041b2886b);
#
#
#             var marker_e291cde07078c0b9ff7aa58766bb2ba9 = L.marker(
#                 [28.56367, -80.57163],
#                 {
# }
#             ).addTo(map_a4c1bb916239ded3bc1967bac8c86dca);
#
#
#             var icon_a908f5e8312c2cc3b345b4f048cfda00 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d389e881c045fe4457cb4ca30c9b0783 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_487222fb5175e02c3d6ee99c458f2cef = $(`&lt;div id=&quot;html_487222fb5175e02c3d6ee99c458f2cef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coastline Point&lt;/div&gt;`)[0];
#                 popup_d389e881c045fe4457cb4ca30c9b0783.setContent(html_487222fb5175e02c3d6ee99c458f2cef);
#
#
#
#         marker_e291cde07078c0b9ff7aa58766bb2ba9.bindPopup(popup_d389e881c045fe4457cb4ca30c9b0783)
#         ;
#
#
#
#
#                 marker_e291cde07078c0b9ff7aa58766bb2ba9.setIcon(icon_a908f5e8312c2cc3b345b4f048cfda00);
#
#
#             var marker_44b446c8796f55fcf2ab09b0e1dbf0b4 = L.marker(
#                 [28.56367, -80.57163],
#                 {
# }
#             ).addTo(map_a4c1bb916239ded3bc1967bac8c86dca);
#
#
#             var div_icon_043d37ca39c9798e755f4463e4fd0fc1 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:#d35400;\&quot;\u003e\u003cb\u003e0.58 KM\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [150, 36],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_44b446c8796f55fcf2ab09b0e1dbf0b4.setIcon(div_icon_043d37ca39c9798e755f4463e4fd0fc1);
#
#
#                 marker_44b446c8796f55fcf2ab09b0e1dbf0b4.setIcon(div_icon_043d37ca39c9798e755f4463e4fd0fc1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# TODO): Dibujar una línea (PolyLine) entre un sitio de lanzamiento y el punto de la costa seleccionado.

# %%
import folium
from folium.features import DivIcon
from math import radians, cos, sin, asin, sqrt

# Función para calcular distancia con fórmula Haversine
def haversine(lat1, lon1, lat2, lon2):
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    r = 6371
    return c * r

# Coordenadas
launch_site = [28.5623, -80.5774]
coastline = [28.56367, -80.57163]

# Calcular distancia
distance = haversine(launch_site[0], launch_site[1], coastline[0], coastline[1])

# Crear el mapa
site_map = folium.Map(location=launch_site, zoom_start=14)

# Marcadores
folium.Marker(launch_site, popup='Launch Site', icon=folium.Icon(color='blue')).add_to(site_map)
folium.Marker(coastline, popup='Coastline', icon=folium.Icon(color='green')).add_to(site_map)

# Texto con la distancia
folium.Marker(
    location=coastline,
    icon=DivIcon(
        icon_size=(150,36),
        icon_anchor=(0,0),
        html='<div style="font-size: 12px; color:#d35400;"><b>{:.2f} KM</b></div>'.format(distance),
    )
).add_to(site_map)

# 👉 Dibujar la línea entre los dos puntos
coordinates = [launch_site, coastline]
line = folium.PolyLine(locations=coordinates, weight=2, color='blue')
site_map.add_child(line)

# Mostrar mapa
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b4839de5e16dc87557a52bdfb72fa974 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b4839de5e16dc87557a52bdfb72fa974&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b4839de5e16dc87557a52bdfb72fa974 = L.map(
#                 &quot;map_b4839de5e16dc87557a52bdfb72fa974&quot;,
#                 {
#                     center: [28.5623, -80.5774],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5bc028a7a95ae9dec5d40910c027ff5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c5bc028a7a95ae9dec5d40910c027ff5.addTo(map_b4839de5e16dc87557a52bdfb72fa974);
#
#
#             var marker_00528f87518d48910e168b7ab39fa748 = L.marker(
#                 [28.5623, -80.5774],
#                 {
# }
#             ).addTo(map_b4839de5e16dc87557a52bdfb72fa974);
#
#
#             var icon_9a18bd6cae177a2e96c72f4003306582 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_adda64a917b494cd993982ddf232aa78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6862d9b42fe45bf6881e0fcec0b05ed = $(`&lt;div id=&quot;html_b6862d9b42fe45bf6881e0fcec0b05ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site&lt;/div&gt;`)[0];
#                 popup_adda64a917b494cd993982ddf232aa78.setContent(html_b6862d9b42fe45bf6881e0fcec0b05ed);
#
#
#
#         marker_00528f87518d48910e168b7ab39fa748.bindPopup(popup_adda64a917b494cd993982ddf232aa78)
#         ;
#
#
#
#
#                 marker_00528f87518d48910e168b7ab39fa748.setIcon(icon_9a18bd6cae177a2e96c72f4003306582);
#
#
#             var marker_7cda2fa765e0a284e55548bf842ef936 = L.marker(
#                 [28.56367, -80.57163],
#                 {
# }
#             ).addTo(map_b4839de5e16dc87557a52bdfb72fa974);
#
#
#             var icon_47a1ceadfb23daf745a8b9cbeef68764 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d992aeb95273b414b2e96fd290c5cdf8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f2c50e8ff0dbd098667c0f5b1f2c459 = $(`&lt;div id=&quot;html_5f2c50e8ff0dbd098667c0f5b1f2c459&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coastline&lt;/div&gt;`)[0];
#                 popup_d992aeb95273b414b2e96fd290c5cdf8.setContent(html_5f2c50e8ff0dbd098667c0f5b1f2c459);
#
#
#
#         marker_7cda2fa765e0a284e55548bf842ef936.bindPopup(popup_d992aeb95273b414b2e96fd290c5cdf8)
#         ;
#
#
#
#
#                 marker_7cda2fa765e0a284e55548bf842ef936.setIcon(icon_47a1ceadfb23daf745a8b9cbeef68764);
#
#
#             var marker_2f513fc391496e3640654a684dd43621 = L.marker(
#                 [28.56367, -80.57163],
#                 {
# }
#             ).addTo(map_b4839de5e16dc87557a52bdfb72fa974);
#
#
#             var div_icon_e71f4af80c0ede1a5c24fa616dfac5aa = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:#d35400;\&quot;\u003e\u003cb\u003e0.58 KM\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [150, 36],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_2f513fc391496e3640654a684dd43621.setIcon(div_icon_e71f4af80c0ede1a5c24fa616dfac5aa);
#
#
#                 marker_2f513fc391496e3640654a684dd43621.setIcon(div_icon_e71f4af80c0ede1a5c24fa616dfac5aa);
#
#
#             var poly_line_054fb3162d2eb2a08ed86bf167fcee1a = L.polyline(
#                 [[28.5623, -80.5774], [28.56367, -80.57163]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_b4839de5e16dc87557a52bdfb72fa974);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100

# %% [markdown]
# TODO): De manera similar, puedes dibujar una línea entre un sitio de lanzamiento y la ciudad, vía férrea, autopista, etc. más cercana. Primero necesitas usar MousePosition para encontrar sus coordenadas en el mapa.

# %%
import folium
from folium.features import DivIcon
from math import radians, cos, sin, asin, sqrt

# Función para calcular la distancia
def haversine(lat1, lon1, lat2, lon2):
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    r = 6371
    return c * r

# Coordenadas del sitio de lanzamiento
launch_site = [28.5623, -80.5774]

# Coordenadas del punto cercano (ciudad, tren, autopista, etc.)
# Reemplaza por las que tú encuentres con MousePosition
closest_point = [28.6100, -80.8000]  # <- ejemplo de una ciudad

# Calcular distancia
distance = haversine(launch_site[0], launch_site[1], closest_point[0], closest_point[1])

# Crear el mapa
site_map = folium.Map(location=launch_site, zoom_start=10)

# Marcador sitio de lanzamiento
folium.Marker(
    launch_site,
    popup='Launch Site',
    icon=folium.Icon(color='blue')
).add_to(site_map)

# Marcador del punto cercano (ciudad, vía, autopista)
folium.Marker(
    closest_point,
    popup='Punto cercano',
    icon=folium.Icon(color='purple')
).add_to(site_map)

# Mostrar distancia en texto
folium.Marker(
    location=closest_point,
    icon=DivIcon(
        icon_size=(150,36),
        icon_anchor=(0,0),
        html='<div style="font-size: 12px; color:#800080;"><b>{:.2f} KM</b></div>'.format(distance),
    )
).add_to(site_map)

# Dibujar línea entre el sitio de lanzamiento y el punto cercano
folium.PolyLine(
    locations=[launch_site, closest_point],
    weight=2,
    color='purple'
).add_to(site_map)

# Mostrar mapa
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8212eb188e2239f9365ab115445eac0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8212eb188e2239f9365ab115445eac0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8212eb188e2239f9365ab115445eac0a = L.map(
#                 &quot;map_8212eb188e2239f9365ab115445eac0a&quot;,
#                 {
#                     center: [28.5623, -80.5774],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_87bbda71b92a1a82dfc8156135c89ec8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_87bbda71b92a1a82dfc8156135c89ec8.addTo(map_8212eb188e2239f9365ab115445eac0a);
#
#
#             var marker_2aea7a395499a06634ddac2a70093a81 = L.marker(
#                 [28.5623, -80.5774],
#                 {
# }
#             ).addTo(map_8212eb188e2239f9365ab115445eac0a);
#
#
#             var icon_9dba58b482d86148f19b868d70ede05c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d4aeaedf44ae97500a393cff5bd5ece5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fdc84f5a5827158034212dc5af4dee47 = $(`&lt;div id=&quot;html_fdc84f5a5827158034212dc5af4dee47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site&lt;/div&gt;`)[0];
#                 popup_d4aeaedf44ae97500a393cff5bd5ece5.setContent(html_fdc84f5a5827158034212dc5af4dee47);
#
#
#
#         marker_2aea7a395499a06634ddac2a70093a81.bindPopup(popup_d4aeaedf44ae97500a393cff5bd5ece5)
#         ;
#
#
#
#
#                 marker_2aea7a395499a06634ddac2a70093a81.setIcon(icon_9dba58b482d86148f19b868d70ede05c);
#
#
#             var marker_ecd2b6826738722e9df5c4fdd11e3d11 = L.marker(
#                 [28.61, -80.8],
#                 {
# }
#             ).addTo(map_8212eb188e2239f9365ab115445eac0a);
#
#
#             var icon_5fbfdd59a3c44b91108259afbd4ba5a0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8cb131646b6e0718257f3a4a74b1f5b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ac6b769b579f1950c78b77e1ea2d440 = $(`&lt;div id=&quot;html_0ac6b769b579f1950c78b77e1ea2d440&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto cercano&lt;/div&gt;`)[0];
#                 popup_8cb131646b6e0718257f3a4a74b1f5b7.setContent(html_0ac6b769b579f1950c78b77e1ea2d440);
#
#
#
#         marker_ecd2b6826738722e9df5c4fdd11e3d11.bindPopup(popup_8cb131646b6e0718257f3a4a74b1f5b7)
#         ;
#
#
#
#
#                 marker_ecd2b6826738722e9df5c4fdd11e3d11.setIcon(icon_5fbfdd59a3c44b91108259afbd4ba5a0);
#
#
#             var marker_bbb7e1a17b66a94bf0293d6f77e39b68 = L.marker(
#                 [28.61, -80.8],
#                 {
# }
#             ).addTo(map_8212eb188e2239f9365ab115445eac0a);
#
#
#             var div_icon_09ed066c152cdcdf2189e6c15e564f47 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:#800080;\&quot;\u003e\u003cb\u003e22.37 KM\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [150, 36],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_bbb7e1a17b66a94bf0293d6f77e39b68.setIcon(div_icon_09ed066c152cdcdf2189e6c15e564f47);
#
#
#                 marker_bbb7e1a17b66a94bf0293d6f77e39b68.setIcon(div_icon_09ed066c152cdcdf2189e6c15e564f47);
#
#
#             var poly_line_85bf9bd2239ae07bb4763baf6d0166c6 = L.polyline(
#                 [[28.5623, -80.5774], [28.61, -80.8]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_8212eb188e2239f9365ab115445eac0a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;to

# %% [markdown]
# ✍️ Análisis de proximidades de los sitios de lanzamiento
# Luego de trazar líneas desde el sitio de lanzamiento hacia diferentes puntos de interés (costa, autopistas, vías férreas y ciudad), se pueden realizar las siguientes observaciones:
#
# ¿Están los sitios de lanzamiento cerca de vías férreas?
# Sí. El sitio de lanzamiento analizado se encuentra en proximidad directa a una vía férrea, lo que facilita el transporte de equipos pesados y componentes necesarios para el lanzamiento.
#
# ¿Están los sitios de lanzamiento cerca de autopistas?
# Sí. Se observan autopistas principales a corta distancia del sitio, lo cual permite un acceso terrestre eficiente tanto para personal como para logística.
#
# ¿Están los sitios de lanzamiento cerca de la costa?
# Sí. El sitio está ubicado a pocos kilómetros de la costa, lo que es ideal por razones de seguridad (permitiendo que las etapas caigan en el océano) y también por la facilidad de transporte marítimo.
#
# ¿Se mantienen los sitios de lanzamiento a cierta distancia de las ciudades?
# Efectivamente. Aunque hay ciudades relativamente cercanas (como Titusville), los sitios de lanzamiento se mantienen alejados de zonas urbanas densas, probablemente por razones de seguridad y control de riesgos en caso de fallos.
#
# ✅ Conclusión
# Los sitios de lanzamiento analizados muestran una ubicación estratégica: cercanos a infraestructuras clave como autopistas y ferrocarriles, pero al mismo tiempo lo suficientemente alejados de áreas urbanas densas y cerca del mar, lo cual es ideal para operaciones aeroespaciales seguras y eficientes.

# %% [markdown]
# Después de trazar las líneas de distancia hacia los puntos cercanos, puedes responder fácilmente las siguientes preguntas:
# ¿Los sitios de lanzamiento están cerca de vías férreas?
#
# ¿Los sitios de lanzamiento están cerca de autopistas?
#
# ¿Los sitios de lanzamiento están cerca de la costa?
#
# ¿Los sitios de lanzamiento mantienen cierta distancia respecto a las ciudades?
#
# Además, intenta explicar tus hallazgos.
